# %%
# importing important libraries 

import pandas as pd
import numpy as np

# %%
# loading the dataset to pandas and creating dataframe

data = pd.read_csv("..//data//owid-covid-data.csv")
df = pd.DataFrame(data)

# %%
# understanding the data

print(df.head(10))  #first 10 rows of the dataset
print(df.tail()) # last 5 rows
df.columns # total columns with their names 
print(df.columns.dtype) # datatype of each column
print(df.columns.isnull()) # checking for any null values in the column

# %%
# some statistical info 

# df.info()
# df.describe()
df.dtypes
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   26525
# location                                        0
# date                                            0
# total_cases                                 17631
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       416024
# excess_mortality_cumulative                416024
# excess_mortality                           416024
# excess_mortality_cumulative_per_million    416024
# Length: 67, dtype: int64

# %%
df.columns

# %%
# filtering out important columns 

covid_cleaned = df["iso_code",""]
